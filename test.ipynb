# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from ydata_profiling import ProfileReport

df = pd.read_csv('~/Downloads/candidates/candidates.csv', sep=';')

profile = ProfileReport(df, title="Profiling Report")


# As a JSON string
json_data = profile.to_json()

# As a file
profile.to_file("your_report.json")
# Out:
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
# Render JSON:   0%|          | 0/1 [00:00<?, ?it/s]
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
# load json as a dict
import json
with open('your_report.json') as f:
    data = json.load(f)

pop_keys = ['analysis', 'scatter', 'correlations', 'missing', 'package', 'sample', 'duplicates']
for key in pop_keys:
    data.pop(key)

data
# Out:
# {'table': {'n': 50000,
#   'n_var': 10,
#   'memory_size': 4000128,
#   'record_size': 80.00256,
#   'n_cells_missing': 0,
#   'n_vars_with_missing': 0,
#   'n_vars_all_missing': 0,
#   'p_cells_missing': 0.0,
#   'types': {'Categorical': 7, 'Numeric': 3},
#   'n_duplicates': 0,
#   'p_duplicates': 0.0},
#  'variables': {'First Name': {'n_distinct': 3007,
#    'p_distinct': 0.06014,
#    'is_unique': False,
#    'n_unique': 0,
#    'p_unique': 0.0,
#    'type': 'Categorical',
#    'hashable': True,
#    'value_counts_without_nan': {'Sarai': 33,
#     'Elyse': 32,
#     'Eva': 31,
#     'Anabel': 31,
#     'Nayeli': 30,
#     'Luna': 29,
#     'Buster': 29,
#     'Lazaro': 28,
#     'Ari': 28,
#     'Golda': 28,
#     'Jake': 28,
#     'Terrell': 28,
#     'Bridget': 28,
#     'Wyman': 28,
#     'Tyler': 28,
#     'Jena': 28,
#     'Veronica': 28,
#     'Glennie': 27,
#     'Bret': 27,
#     'Zechariah': 27,
#     'Alvina': 27,
#     'Yasmin': 27,
#     'Kelvin': 27,
#     'Brennon': 27,
#     'Elenor': 27,
#     'Tremayne': 27,
#     'Marc': 27,
#     'Reginald': 27,
#     'Else': 27,
#     'Stevie': 26,
#     'Lavern': 26,
#     'Rosalia': 26,
#     'Ola': 26,
#     'Tyrell': 26,
#     'Maci': 26,
#     'Emile': 26,
#     'Roselyn': 26,
#     'Ashlee': 26,
#     'Haylee': 26,
#     'Edd': 26,
#     'Cecile': 26,
#     'Margret': 26,
#     'Mara': 26,
#     'Bridgette': 26,
#     'Verner': 26,
#     'Alyce': 26,
#     'Rowan': 26,
#     'Edna': 26,
#     'Barton': 26,
#     'Cameron': 26,
#     'Destin': 26,
#     'Alek': 26,
#     'Elva': 26,
#     'Marcia': 26,
#     'Deon': 26,
#     'Earlene': 26,
#     'Etha': 26,
#     'Tressie': 26,
#     'Watson': 25,
#     'Camryn': 25,
#     'Thalia': 25,
#     'Milton': 25,
#     'Stanley': 25,
#     'Braeden': 25,
#     'Zoila': 25,
#     'Tianna': 25,
#     'Jimmie': 25,
#     'Shaylee': 25,
#     'Columbus': 25,
#     'Cleora': 25,
#     'Elouise': 25,
#     'Angeline': 25,
#     'Julien': 25,
#     'Green': 25,
#     'Garry': 25,
#     'Jaylon': 25,
#     'Ryan': 25,
#     'Nya': 25,
#     'Rachael': 25,
#     'Curt': 25,
#     'Jaleel': 25,
#     'Florida': 25,
#     'Saul': 25,
#     'Jaime': 25,
#     'Frida': 25,
#     'Mariam': 25,
#     'Herminio': 25,
#     'Lolita': 25,
#     'Genoveva': 25,
#     'Mustafa': 25,
#     'Dina': 25,
#     'Cali': 25,
#     'Johathan': 25,
#     'Orrin': 25,
#     'Cassandre': 25,
#     'Genevieve': 25,
#     'Esther': 25,
#     'Brooke': 25,
#     'Isabel': 25,
#     'Casimer': 24,
#     'Charlie': 24,
#     'Katherine': 24,
#     'Anibal': 24,
#     'Lorena': 24,
#     'Hester': 24,
#     'Beth': 24,
#     'Grace': 24,
#     'Stacey': 24,
#     'Brent': 24,
#     'Nichole': 24,
#     'Samara': 24,
#     'Jalen': 24,
#     'Eliezer': 24,
#     'Melisa': 24,
#     'Effie': 24,
#     'Marina': 24,
#     'Lauryn': 24,
#     'Lawson': 24,
#     'Sister': 24,
#     'Obie': 24,
#     'Alta': 24,
#     'Jayson': 24,
#     'Sydney': 24,
#     'Ernest': 24,
#     'Abbigail': 24,
#     'Torrey': 24,
#     'Brock': 24,
#     'Lourdes': 24,
#     'Maye': 24,
#     'Luz': 24,
#     'Damien': 24,
#     'Shawn': 24,
#     'Ulices': 24,
#     'Rico': 24,
#     'Marty': 24,
#     'Faustino': 24,
#     'Jovany': 24,
#     'Henriette': 24,
#     'Janice': 24,
#     'Eduardo': 24,
#     'Mozelle': 24,
#     'Denis': 24,
#     'Gabrielle': 24,
#     'Clementina': 24,
#     'Claudie': 24,
#     'Jairo': 24,
#     'Sadie': 24,
#     'Josefina': 24,
#     'Tod': 24,
#     'Brook': 24,
#     'Kendra': 24,
#     'Ewell': 24,
#     'Felicita': 24,
#     'Gino': 24,
#     'Friedrich': 23,
#     'Emmalee': 23,
#     'Theodora': 23,
#     'Amira': 23,
#     'Kallie': 23,
#     'Bobbie': 23,
#     'Deion': 23,
#     'Kale': 23,
#     'Shany': 23,
#     'Kennedi': 23,
#     'Eunice': 23,
#     'Emil': 23,
#     'Dolly': 23,
#     'Aaliyah': 23,
#     'Angelita': 23,
#     'Montana': 23,
#     'Zane': 23,
#     'Jeremy': 23,
#     'Jolie': 23,
#     'Lewis': 23,
#     'Rasheed': 23,
#     'Lorenzo': 23,
#     'Matilde': 23,
#     'Maybelle': 23,
#     'Craig': 23,
#     'Velma': 23,
#     'Dusty': 23,
#     'Dario': 23,
#     'Kylie': 23,
#     'Hortense': 23,
#     'Evie': 23,
#     'Alverta': 23,
#     'Alysha': 23,
#     'Cordie': 23,
#     'Vesta': 23,
#     'Estrella': 23,
#     'Bernadine': 23,
#     'Candelario': 23,
#     'Jacky': 23,
#     'Irving': 23,
#     'Archibald': 23,
#     'Zack': 23,
#     'Lloyd': 23,
#     'Roberta': 23,
#     'Laney': 23,
#     'Kellen': 23,
#     'Dayna': 23,
#     'Derek': 23,
#     'Kaelyn': 23,
#     'Amya': 23,
#     'Concepcion': 23,
#     'Pietro': 23,
#     'Hellen': 23,
#     'Evan': 23,
#     'Emmet': 23,
#     'Janet': 23,
#     'Devante': 23,
#     'Sincere': 23,
#     'Cielo': 23,
#     'Joy': 23,
#     'Vivianne': 23,
#     'Santa': 23,
#     'Lulu': 23,
#     'Blaze': 23,
#     'Arianna': 23,
#     'Claudine': 23,
#     'Wilfrid': 23,
#     'Claude': 23,
#     'Furman': 23,
#     'Maritza': 23,
#     'Modesta': 23,
#     'Fritz': 23,
#     'Rylee': 23,
#     'Mary': 23,
#     'Jettie': 23,
#     'Allison': 23,
#     'Jaclyn': 23,
#     'Kyla': 23,
#     'Hugh': 23,
#     'Harmon': 23,
#     'Rey': 23,
#     'Rhoda': 23,
#     'Hilario': 22,
#     'Millie': 22,
#     'Elna': 22,
#     'Adam': 22,
#     'Dominic': 22,
#     'Ted': 22,
#     'Delilah': 22,
#     'Gracie': 22,
#     'Rogelio': 22,
#     'Laverna': 22,
#     'Jerald': 22,
#     'Crystal': 22,
#     'Lauriane': 22,
#     'Bethel': 22,
#     'Antwon': 22,
#     'Kenny': 22,
#     'Ayden': 22,
#     'Hudson': 22,
#     'Sean': 22,
#     'Jakayla': 22,
#     'Arvid': 22,
#     'Michael': 22,
#     'Carley': 22,
#     'Kelsi': 22,
#     'Paige': 22,
#     'Annalise': 22,
#     'Kristopher': 22,
#     'Luciano': 22,
#     'Donna': 22,
#     'Richie': 22,
#     'Mckenna': 22,
#     'Ward': 22,
#     'Odessa': 22,
#     'Jules': 22,
#     'Maggie': 22,
#     'Wendy': 22,
#     'Caleb': 22,
#     'Richard': 22,
#     'Louie': 22,
#     'Myriam': 22,
#     'Mariah': 22,
#     'Jedediah': 22,
#     'Reinhold': 22,
#     'Fannie': 22,
#     'Neha': 22,
#     'Rebeca': 22,
#     'Brandy': 22,
#     'Dexter': 22,
#     'Hollis': 22,
#     'Birdie': 22,
#     'Aidan': 22,
#     'Geraldine': 22,
#     'Jared': 22,
#     'Mathilde': 22,
#     'Verla': 22,
#     'Heber': 22,
#     'Reagan': 22,
#     'Otha': 22,
#     'Katelin': 22,
#     'Courtney': 22,
#     'Amaya': 22,
#     'Neal': 22,
#     'May': 22,
#     'Carter': 22,
#     'Aubree': 22,
#     'Russel': 22,
#     'Brisa': 22,
#     'Morton': 22,
#     'Libby': 22,
#     'Jamey': 22,
#     'Chanel': 22,
#     'Nasir': 22,
#     'Kenton': 22,
#     'Kristin': 22,
#     'Jada': 22,
#     'Laury': 22,
#     'Itzel': 22,
#     'Garnett': 22,
#     'Whitney': 22,
#     'Alda': 22,
#     'Mikel': 22,
#     'Claire': 22,
#     'Merl': 22,
#     'Osvaldo': 22,
#     'Conrad': 22,
#     'Amani': 22,
#     'Rita': 22,
#     'Jonas': 22,
#     'Delia': 22,
#     'Sven': 22,
#     'Clifford': 22,
#     'Orland': 22,
#     'Breana': 22,
#     'Berry': 22,
#     'Ines': 22,
#     'Enola': 22,
#     'Elsie': 22,
#     'Scotty': 22,
#     'Mackenzie': 22,
#     'Holly': 22,
#     'Ali': 22,
#     'Jesus': 22,
#     'Timmothy': 22,
#     'Fleta': 22,
#     'Estefania': 22,
#     'Hannah': 22,
#     'Heloise': 22,
#     'Dejon': 22,
#     'Niko': 22,
#     'Caleigh': 22,
#     'Meghan': 22,
#     'Drew': 22,
#     'Rodrigo': 22,
#     'Maia': 22,
#     'Jacques': 22,
#     'Andreane': 22,
#     'Skylar': 22,
#     'Brandi': 22,
#     'John': 21,
#     'Lorenza': 21,
#     'Adelbert': 21,
#     'Nels': 21,
#     'Eddie': 21,
#     'Lindsay': 21,
#     'Blanca': 21,
#     'Chaz': 21,
#     'Maurine': 21,
#     'Piper': 21,
#     'Verlie': 21,
#     'Eino': 21,
#     'Rubie': 21,
#     'Esteban': 21,
#     'Destini': 21,
#     'Bridie': 21,
#     'Fermin': 21,
#     'Teresa': 21,
#     'Melissa': 21,
#     'Karianne': 21,
#     'Fletcher': 21,
#     'Gus': 21,
#     'Brycen': 21,
#     'Neoma': 21,
#     'Ezekiel': 21,
#     'Edwina': 21,
#     'Wyatt': 21,
#     'Carroll': 21,
#     'Freida': 21,
#     'Reva': 21,
#     'Lue': 21,
#     'Oscar': 21,
#     'Jabari': 21,
#     'Andres': 21,
#     'Lupe': 21,
#     'Broderick': 21,
#     'Cornelius': 21,
#     'Everett': 21,
#     'Patience': 21,
#     'Kathleen': 21,
#     'Dale': 21,
#     'Susan': 21,
#     'Jude': 21,
#     'Cesar': 21,
#     'Carolyn': 21,
#     'Miller': 21,
#     'Kaylin': 21,
#     'Buddy': 21,
#     'Jacinthe': 21,
#     'Lon': 21,
#     'Bulah': 21,
#     'Abigale': 21,
#     "D'angelo": 21,
#     'Wilfredo': 21,
#     'Tamara': 21,
#     'Lafayette': 21,
#     'Gordon': 21,
#     'Faye': 21,
#     'Brooks': 21,
#     'Murray': 21,
#     'Christa': 21,
#     'Kaia': 21,
#     'Ellen': 21,
#     'Karelle': 21,
#     'Judson': 21,
#     'Quinton': 21,
#     'Korbin': 21,
#     'Thomas': 21,
#     'Augustus': 21,
#     'Deonte': 21,
#     'Liana': 21,
#     'Carmine': 21,
#     'Roberto': 21,
#     'Florencio': 21,
#     'Willa': 21,
#     'Earline': 21,
#     'Reggie': 21,
#     'Amber': 21,
#     'Herta': 21,
#     'Jaren': 21,
#     'Nathan': 21,
#     'Jean': 21,
#     'Syble': 21,
#     'Jeanne': 21,
#     'Alycia': 21,
#     'Taya': 21,
#     'Colby': 21,
#     'Pearl': 21,
#     'Haven': 21,
#     'Emiliano': 21,
#     'Elias': 21,
#     'German': 21,
#     'Reymundo': 21,
#     'Chandler': 21,
#     'Jaycee': 21,
#     'Shana': 21,
#     'Cordelia': 21,
#     'Marlee': 21,
#     'Tanner': 21,
#     'Guillermo': 21,
#     'Mathew': 21,
#     'Cristal': 21,
#     'Rhianna': 21,
#     'Alexane': 21,
#     'Dustin': 21,
#     'Raymundo': 21,
#     'Estella': 21,
#     'Van': 21,
#     'Adell': 21,
#     'Carissa': 21,
#     'Willow': 21,
#     'Kamron': 21,
#     'Trever': 21,
#     'Newell': 21,
#     'Easton': 21,
#     'Merritt': 21,
#     'Keyon': 21,
#     'Shanie': 21,
#     'Ally': 21,
#     'Ruben': 21,
#     'Aurore': 21,
#     'Kiara': 21,
#     'Bernhard': 21,
#     'Gertrude': 21,
#     'Ashton': 21,
#     'Corene': 21,
#     'Grady': 21,
#     'Jonathon': 21,
#     'Ryder': 21,
#     'Dino': 21,
#     'Kristy': 21,
#     'Zelda': 21,
#     'Aleen': 21,
#     'Emilio': 21,
#     'Thea': 21,
#     'Roderick': 21,
#     'Lea': 21,
#     'Wilmer': 21,
#     'Adah': 21,
#     'Hyman': 21,
#     'Sylvan': 21,
#     'Melba': 21,
#     'Joanny': 21,
#     'Jarrell': 21,
#     'Shyanne': 21,
#     'David': 21,
#     'Kurt': 21,
#     'Tracey': 21,
#     'Michelle': 21,
#     'Abel': 21,
#     'Adolfo': 21,
#     'Emilia': 21,
#     'Weston': 21,
#     'Enid': 21,
#     'Greta': 21,
#     'Maymie': 21,
#     'Delpha': 21,
#     'Jayce': 21,
#     'Aileen': 21,
#     'Creola': 20,
#     'Mario': 20,
#     'Valentine': 20,
#     'Rodger': 20,
#     'Devon': 20,
#     'Maida': 20,
#     'Urban': 20,
#     'Lambert': 20,
#     'Fae': 20,
#     'Sunny': 20,
#     'Alba': 20,
#     'Vince': 20,
#     'Berenice': 20,
#     'Alva': 20,
#     'Kip': 20,
#     'Laurence': 20,
#     'Orlando': 20,
#     'Molly': 20,
#     'Angelina': 20,
#     'Cristina': 20,
#     'Donavon': 20,
#     'Irma': 20,
#     'Fanny': 20,
#     'Nelle': 20,
#     'Dolores': 20,
#     'Connor': 20,
#     'Jennings': 20,
#     'Bertha': 20,
#     'Lucienne': 20,
#     'Cleta': 20,
#     'Johnnie': 20,
#     'Elenora': 20,
#     'Sierra': 20,
#     'Aiyana': 20,
#     'Dax': 20,
#     'Jacey': 20,
#     'Linda': 20,
#     'Jeffery': 20,
#     'Cara': 20,
#     'Julianne': 20,
#     'Rosendo': 20,
#     'Stephen': 20,
#     'Ole': 20,
#     'Marge': 20,
#     'Maverick': 20,
#     'Ryleigh': 20,
#     'Kassandra': 20,
#     'Winston': 20,
#     'Jacynthe': 20,
#     'Sadye': 20,
#     'Henry': 20,
#     'Kiarra': 20,
#     'Antwan': 20,
#     'Zelma': 20,
#     'Lexi': 20,
#     'Enos': 20,
#     'Retta': 20,
#     'Demetrius': 20,
#     'Zoe': 20,
#     'Lucie': 20,
#     'Moshe': 20,
#     'Charlotte': 20,
#     'Johnson': 20,
#     'Doug': 20,
#     'Santina': 20,
#     'Kiley': 20,
#     'Lois': 20,
#     'Verona': 20,
#     'Quinten': 20,
#     'Darian': 20,
#     'Xander': 20,
#     'Kali': 20,
#     'Tyshawn': 20,
#     'Susana': 20,
#     'Summer': 20,
#     'Sabryna': 20,
#     'Eveline': 20,
#     'Myra': 20,
#     'Lura': 20,
#     'Russ': 20,
#     'Felton': 20,
#     'Mireille': 20,
#     'Beatrice': 20,
#     'Dessie': 20,
#     'Allie': 20,
#     'Kraig': 20,
#     'Amina': 20,
#     'Bessie': 20,
#     'Selmer': 20,
#     'Adaline': 20,
#     'Arlene': 20,
#     'Giovanny': 20,
#     'Margot': 20,
#     'Jarred': 20,
#     'Kane': 20,
#     'Brady': 20,
#     'Jakob': 20,
#     'Vanessa': 20,
#     'Layla': 20,
#     'Kari': 20,
#     'Jana': 20,
#     'Eda': 20,
#     'Lily': 20,
#     'Lester': 20,
#     'Micaela': 20,
#     'Kelli': 20,
#     'Stefanie': 20,
#     'Myrl': 20,
#     'Lilla': 20,
#     'Daisy': 20,
#     'Brenden': 20,
#     'Jenifer': 20,
#     'Aimee': 20,
#     'Alfredo': 20,
#     'Darien': 20,
#     'Keegan': 20,
#     'Viva': 20,
#     'Kameron': 20,
#     'Collin': 20,
#     'Kaela': 20,
#     'Breanne': 20,
#     'Camden': 20,
#     'Zakary': 20,
#     'Telly': 20,
#     'Betsy': 20,
#     'Ubaldo': 20,
#     'Destany': 20,
#     'Corbin': 20,
#     'Hayden': 20,
#     'Carol': 20,
#     'Agustin': 20,
#     'Chet': 20,
#     'Toney': 20,
#     'Alayna': 20,
#     'Bryce': 20,
#     'Norene': 20,
#     'Isobel': 20,
#     'Katelynn': 20,
#     'Chaya': 20,
#     'Spencer': 20,
#     'Robbie': 20,
#     'Flo': 20,
#     'Deven': 20,
#     'Chasity': 20,
#     'Claud': 20,
#     'Magnolia': 20,
#     'Colin': 20,
#     'Carmen': 20,
#     'Colleen': 20,
#     'Camren': 20,
#     'Nicholas': 20,
#     'Ludwig': 20,
#     'Pasquale': 20,
#     'Evelyn': 20,
#     'Jordi': 20,
#     'Onie': 20,
#     'Lavonne': 20,
#     'Eriberto': 20,
#     'Alaina': 20,
#     'Rupert': 20,
#     'Eleonore': 20,
#     'Katlyn': 20,
#     'Aisha': 20,
#     'Lessie': 20,
#     'Providenci': 20,
#     'Breanna': 20,
#     'Sabrina': 20,
#     'Jeanie': 20,
#     'Maximillian': 20,
#     'Arvel': 20,
#     'Arthur': 20,
#     'Odie': 20,
#     'Carmella': 20,
#     'Thurman': 20,
#     'Tomas': 20,
#     'Joseph': 20,
#     'Orie': 20,
#     'Izabella': 20,
#     'Halie': 20,
#     'Janessa': 20,
#     'Juana': 20,
#     'Rowland': 20,
#     'Dillan': 20,
#     'Webster': 20,
#     'Paula': 20,
#     'Petra': 20,
#     'Nova': 20,
#     'Rocio': 20,
#     'Torrance': 20,
#     'Nils': 20,
#     'Darrin': 20,
#     'Abraham': 20,
#     'Alden': 20,
#     'Hubert': 20,
#     'Luisa': 20,
#     'Lorna': 20,
#     'Abe': 20,
#     'Clarissa': 20,
#     'Bonita': 20,
#     'Paris': 20,
#     'Cristobal': 20,
#     'Clair': 20,
#     'Alyson': 20,
#     'Dwight': 20,
#     'Simone': 19,
#     'Monroe': 19,
#     'Kristoffer': 19,
#     'Erin': 19,
#     'Gwendolyn': 19,
#     'Devan': 19,
#     'Delaney': 19,
#     'Elinore': 19,
#     'River': 19,
#     'Bettie': 19,
#     'Wilford': 19,
#     'Daryl': 19,
#     'Mathias': 19,
#     'Abdullah': 19,
#     'Bernie': 19,
#     'Deborah': 19,
#     'Emmanuelle': 19,
#     'Jewell': 19,
#     'Cheyenne': 19,
#     'Ursula': 19,
#     'Israel': 19,
#     'Carolyne': 19,
#     'April': 19,
#     'Ophelia': 19,
#     'Theron': 19,
#     'Demarcus': 19,
#     'Cortez': 19,
#     'Dejah': 19,
#     'Uriel': 19,
#     'Crawford': 19,
#     'Winona': 19,
#     'Camille': 19,
#     'Giovani': 19,
#     'Maudie': 19,
#     'Dean': 19,
#     'Adrianna': 19,
#     'Precious': 19,
#     'Freeman': 19,
#     'Jany': 19,
#     'Kamren': 19,
#     'Sharon': 19,
#     'Torey': 19,
#     'Gwen': 19,
#     'Floy': 19,
#     'Berniece': 19,
#     'Tyson': 19,
#     'Laverne': 19,
#     'Blanche': 19,
#     'Bartholome': 19,
#     'Gladys': 19,
#     'Joshuah': 19,
#     'Ryley': 19,
#     'Otilia': 19,
#     'Noah': 19,
#     'Daija': 19,
#     'Imelda': 19,
#     'Lizeth': 19,
#     'Kendall': 19,
#     'Kamille': 19,
#     'Fiona': 19,
#     'Shyann': 19,
#     'Russell': 19,
#     'Florence': 19,
#     'Lexus': 19,
#     'Immanuel': 19,
#     'Devonte': 19,
#     'Kris': 19,
#     'Sim': 19,
#     'Madelyn': 19,
#     'Elmo': 19,
#     'Zella': 19,
#     'Vida': 19,
#     'Esmeralda': 19,
#     'Darryl': 19,
#     'Ana': 19,
#     'Quentin': 19,
#     'Giovanni': 19,
#     'Cullen': 19,
#     'Ashleigh': 19,
#     'Gretchen': 19,
#     'Gussie': 19,
#     'Oda': 19,
#     'Mckayla': 19,
#     'Rowena': 19,
#     'Kellie': 19,
#     'Vallie': 19,
#     'Keon': 19,
#     'Elmira': 19,
#     'Ellsworth': 19,
#     'Alberto': 19,
#     'Joe': 19,
#     'Evert': 19,
#     'Tristin': 19,
#     'Katharina': 19,
#     'Geo': 19,
#     'Loyce': 19,
#     'Will': 19,
#     'Blair': 19,
#     'Marlene': 19,
#     'Amie': 19,
#     'Rozella': 19,
#     'Price': 19,
#     'Cleve': 19,
#     'Okey': 19,
#     'Zackary': 19,
#     'Kacie': 19,
#     'Francis': 19,
#     'Bernita': 19,
#     'Easter': 19,
#     'Alvah': 19,
#     'Ike': 19,
#     'Della': 19,
#     'Eileen': 19,
#     'Burdette': 19,
#     'Pink': 19,
#     'Thelma': 19,
#     'Annamae': 19,
#     'Enrique': 19,
#     'Eden': 19,
#     'Hulda': 19,
#     'Everardo': 19,
#     'Mafalda': 19,
#     'Cordia': 19,
#     'Flossie': 19,
#     'Nigel': 19,
#     'Bertram': 19,
#     'Quincy': 19,
#     'Gustave': 19,
#     'Duane': 19,
#     'Mabel': 19,
#     'Hadley': 19,
#     'Kiera': 19,
#     'Alfred': 19,
#     'Icie': 19,
#     'Elbert': 19,
#     'Melody': 19,
#     'Arely': 19,
#     'Royal': 19,
#     'Lila': 19,
#     'Micah': 19,
#     'Zachery': 19,
#     'Keshaun': 19,
#     'Rahsaan': 19,
#     'Nick': 19,
#     'Finn': 19,
#     'Reece': 19,
#     'Emelia': 19,
#     'Winifred': 19,
#     'Carolina': 19,
#     'Violette': 19,
#     'Myles': 19,
#     'Haleigh': 19,
#     'Norris': 19,
#     'Shaniya': 19,
#     'Gene': 19,
#     'Rene': 19,
#     'Guadalupe': 19,
#     'Carlee': 19,
#     'Yessenia': 19,
#     'Georgette': 19,
#     'Jazmyn': 19,
#     'Lisette': 19,
#     'Kianna': 19,
#     'Carlos': 19,
#     'Kareem': 19,
#     'Sigmund': 19,
#     'Winfield': 19,
#     'Rhiannon': 19,
#     'Jasen': 19,
#     'Isabell': 19,
#     'Houston': 19,
#     'Yvonne': 19,
#     'Agustina': 19,
#     'Dedrick': 19,
#     'Constance': 19,
#     'Ruthie': 19,
#     'Garnet': 19,
#     'Christ': 19,
#     'Wayne': 19,
#     'Thora': 19,
#     'Melyna': 19,
#     'Travon': 19,
#     'Nellie': 19,
#     'Efrain': 19,
#     'Estel': 19,
#     'Jerrod': 19,
#     'Raphael': 19,
#     'Rachelle': 19,
#     'Laura': 19,
#     'Amalia': 19,
#     'Malcolm': 19,
#     'Aliya': 19,
#     'Greyson': 19,
#     'Leland': 19,
#     'Oswaldo': 19,
#     'Filomena': 19,
#     'Raegan': 19,
#     'Celia': 19,
#     'Fausto': 19,
#     'Mercedes': 19,
#     'Barbara': 19,
#     'Jaylen': 19,
#     'Anderson': 19,
#     'Amy': 19,
#     'Alfreda': 19,
#     'Magali': 18,
#     'Ima': 18,
#     'Rigoberto': 18,
#     'Sydnee': 18,
#     'Gerson': 18,
#     'Catherine': 18,
#     'Frederik': 18,
#     'Domenic': 18,
#     'Anastacio': 18,
#     'Aracely': 18,
#     'Gabriella': 18,
#     'Erica': 18,
#     'Demarco': 18,
#     'Haylie': 18,
#     'Abdul': 18,
#     'Al': 18,
#     'Kian': 18,
#     'Liam': 18,
#     'Napoleon': 18,
#     'Sandrine': 18,
#     'Geovanny': 18,
#     'Rosemarie': 18,
#     'Ollie': 18,
#     'Angelo': 18,
#     'Kaya': 18,
#     'Randal': 18,
#     'Tania': 18,
#     'Nikko': 18,
#     'Aniyah': 18,
#     'Timothy': 18,
#     'Tiara': 18,
#     'Hollie': 18,
#     'Brionna': 18,
#     'Lonnie': 18,
#     'Oren': 18,
#     'Gabriel': 18,
#     'Hunter': 18,
#     'Graciela': 18,
#     'Stan': 18,
#     'Amiya': 18,
#     'Heather': 18,
#     'Vickie': 18,
#     'Dedric': 18,
#     'Rosella': 18,
#     'Letitia': 18,
#     'Marian': 18,
#     'Doyle': 18,
#     'Lilian': 18,
#     'Lucy': 18,
#     'Elwin': 18,
#     'Chyna': 18,
#     'Destinee': 18,
#     'Ronaldo': 18,
#     'Arielle': 18,
#     'Aliza': 18,
#     'Carrie': 18,
#     'Josiah': 18,
#     'Alanis': 18,
#     'Clare': 18,
#     'Brando': 18,
#     'Lacy': 18,
#     'Jovani': 18,
#     'Polly': 18,
#     'Xzavier': 18,
#     'Hosea': 18,
#     'Gennaro': 18,
#     'Jaunita': 18,
#     'Modesto': 18,
#     'Salma': 18,
#     'Julian': 18,
#     'Augusta': 18,
#     'Daisha': 18,
#     'Leonard': 18,
#     'Eudora': 18,
#     'Darlene': 18,
#     'Zion': 18,
#     'Mabelle': 18,
#     'Yolanda': 18,
#     ...},
#    'value_counts_index_sorted': {'Aaliyah': 23,
#     'Aaron': 13,
#     'Abagail': 15,
#     'Abbey': 17,
#     'Abbie': 16,
#     'Abbigail': 24,
#     'Abby': 11,
#     'Abdiel': 16,
#     'Abdul': 18,
#     'Abdullah': 19,
#     'Abe': 20,
#     'Abel': 21,
#     'Abelardo': 8,
#     'Abigail': 16,
#     'Abigale': 21,
#     'Abigayle': 12,
#     'Abner': 9,
#     'Abraham': 20,
#     'Ada': 13,
#     'Adah': 21,
#     'Adalberto': 13,
#     'Adaline': 20,
#     'Adam': 22,
#     'Adan': 13,
#     'Addie': 15,
#     'Addison': 15,
#     'Adela': 16,
#     'Adelbert': 21,
#     'Adele': 16,
#     'Adelia': 16,
#     'Adeline': 16,
#     'Adell': 21,
#     'Adella': 10,
#     'Adelle': 16,
#     'Aditya': 17,
#     'Adolf': 16,
#     'Adolfo': 21,
#     'Adolph': 14,
#     'Adolphus': 13,
#     'Adonis': 12,
#     'Adrain': 8,
#     'Adrian': 15,
#     'Adriana': 17,
#     'Adrianna': 19,
#     'Adriel': 15,
#     'Adrien': 17,
#     'Adrienne': 13,
#     'Afton': 15,
#     'Aglae': 15,
#     'Agnes': 15,
#     'Agustin': 20,
#     'Agustina': 19,
#     'Ahmad': 16,
#     'Ahmed': 17,
#     'Aida': 12,
#     'Aidan': 22,
#     'Aiden': 16,
#     'Aileen': 21,
#     'Aimee': 20,
#     'Aisha': 20,
#     'Aiyana': 20,
#     'Akeem': 14,
#     'Al': 18,
#     'Alaina': 20,
#     'Alan': 16,
#     'Alana': 18,
#     'Alanis': 18,
#     'Alanna': 18,
#     'Alayna': 20,
#     'Alba': 20,
#     'Albert': 17,
#     'Alberta': 10,
#     'Albertha': 17,
#     'Alberto': 19,
#     'Albin': 17,
#     'Albina': 14,
#     'Alda': 22,
#     'Alden': 20,
#     'Alec': 15,
#     'Aleen': 21,
#     'Alejandra': 17,
#     'Alejandrin': 16,
#     'Alek': 26,
#     'Alena': 15,
#     'Alene': 15,
#     'Alessandra': 17,
#     'Alessandro': 18,
#     'Alessia': 14,
#     'Aletha': 12,
#     'Alex': 15,
#     'Alexa': 15,
#     'Alexander': 13,
#     'Alexandra': 10,
#     'Alexandre': 17,
#     'Alexandrea': 10,
#     'Alexandria': 10,
#     'Alexandrine': 16,
#     'Alexandro': 17,
#     'Alexane': 21,
#     'Alexanne': 16,
#     'Alexie': 15,
#     'Alexis': 17,
#     'Alexys': 16,
#     'Alexzander': 11,
#     'Alf': 13,
#     'Alfonso': 18,
#     'Alfonzo': 17,
#     'Alford': 15,
#     'Alfred': 19,
#     'Alfreda': 19,
#     'Alfredo': 20,
#     'Ali': 22,
#     'Alia': 14,
#     'Alice': 10,
#     'Alicia': 11,
#     'Alisa': 13,
#     'Alisha': 18,
#     'Alison': 13,
#     'Alivia': 15,
#     'Aliya': 19,
#     'Aliyah': 10,
#     'Aliza': 18,
#     'Alize': 15,
#     'Allan': 15,
#     'Allen': 11,
#     'Allene': 13,
#     'Allie': 20,
#     'Allison': 23,
#     'Ally': 21,
#     'Alphonso': 17,
#     'Alta': 24,
#     'Althea': 14,
#     'Alva': 20,
#     'Alvah': 19,
#     'Alvena': 15,
#     'Alvera': 14,
#     'Alverta': 23,
#     'Alvina': 27,
#     'Alvis': 16,
#     'Alyce': 26,
#     'Alycia': 21,
#     'Alysa': 14,
#     'Alysha': 23,
#     'Alyson': 20,
#     'Alysson': 18,
#     'Amalia': 19,
#     'Amanda': 15,
#     'Amani': 22,
#     'Amara': 9,
#     'Amari': 12,
#     'Amaya': 22,
#     'Amber': 21,
#     'Ambrose': 16,
#     'Amelia': 10,
#     'Amelie': 14,
#     'Amely': 16,
#     'America': 15,
#     'Americo': 7,
#     'Amie': 19,
#     'Amina': 20,
#     'Amir': 17,
#     'Amira': 23,
#     'Amiya': 18,
#     'Amos': 14,
#     'Amparo': 16,
#     'Amy': 19,
#     'Amya': 23,
#     'Ana': 19,
#     'Anabel': 31,
#     'Anabelle': 17,
#     'Anahi': 11,
#     'Anais': 9,
#     'Anastacio': 18,
#     'Anastasia': 13,
#     'Anderson': 19,
#     'Andre': 15,
#     'Andreane': 22,
#     'Andreanne': 16,
#     'Andres': 21,
#     'Andrew': 15,
#     'Andy': 13,
#     'Angel': 15,
#     'Angela': 16,
#     'Angelica': 15,
#     'Angelina': 20,
#     'Angeline': 25,
#     'Angelita': 23,
#     'Angelo': 18,
#     'Angie': 16,
#     'Angus': 12,
#     'Anibal': 24,
#     'Anika': 9,
#     'Anissa': 14,
#     'Anita': 13,
#     'Aniya': 17,
#     'Aniyah': 18,
#     'Anjali': 11,
#     'Anna': 17,
#     'Annabel': 11,
#     'Annabell': 15,
#     'Annabelle': 15,
#     'Annalise': 22,
#     'Annamae': 19,
#     'Annamarie': 13,
#     'Anne': 13,
#     'Annetta': 12,
#     'Annette': 17,
#     'Annie': 14,
#     'Ansel': 11,
#     'Ansley': 18,
#     'Anthony': 13,
#     'Antoinette': 17,
#     'Antone': 17,
#     'Antonetta': 5,
#     'Antonette': 18,
#     'Antonia': 16,
#     'Antonietta': 13,
#     'Antonina': 17,
#     'Antonio': 16,
#     'Antwan': 20,
#     'Antwon': 22,
#     'Anya': 15,
#     'April': 19,
#     'Ara': 14,
#     'Araceli': 9,
#     'Aracely': 18,
#     'Arch': 11,
#     'Archibald': 23,
#     'Ardella': 16,
#     'Arden': 16,
#     'Ardith': 15,
#     'Arely': 19,
#     'Ari': 28,
#     'Ariane': 15,
#     'Arianna': 23,
#     'Aric': 13,
#     'Ariel': 13,
#     'Arielle': 18,
#     'Arjun': 13,
#     'Arlene': 20,
#     'Arlie': 12,
#     'Arlo': 17,
#     'Armand': 17,
#     'Armando': 10,
#     'Armani': 16,
#     'Arnaldo': 11,
#     'Arne': 16,
#     'Arno': 17,
#     'Arnold': 13,
#     'Arnoldo': 15,
#     'Arnulfo': 13,
#     'Aron': 15,
#     'Art': 17,
#     'Arthur': 20,
#     'Arturo': 16,
#     'Arvel': 20,
#     'Arvid': 22,
#     'Arvilla': 12,
#     'Aryanna': 11,
#     'Asa': 11,
#     'Asha': 16,
#     'Ashlee': 26,
#     'Ashleigh': 19,
#     'Ashley': 17,
#     'Ashly': 14,
#     'Ashlynn': 15,
#     'Ashton': 21,
#     'Ashtyn': 15,
#     'Asia': 10,
#     'Assunta': 13,
#     'Astrid': 10,
#     'Athena': 11,
#     'Aubree': 22,
#     'Aubrey': 17,
#     'Audie': 18,
#     'Audra': 15,
#     'Audreanne': 8,
#     'Audrey': 17,
#     'August': 16,
#     'Augusta': 18,
#     'Augustine': 15,
#     'Augustus': 21,
#     'Aurelia': 8,
#     'Aurelie': 17,
#     'Aurelio': 15,
#     'Aurore': 21,
#     'Austen': 18,
#     'Austin': 13,
#     'Austyn': 12,
#     'Autumn': 11,
#     'Ava': 15,
#     'Avery': 14,
#     'Avis': 16,
#     'Axel': 13,
#     'Ayana': 16,
#     'Ayden': 22,
#     'Ayla': 17,
#     'Aylin': 13,
#     'Baby': 11,
#     'Bailee': 15,
#     'Bailey': 16,
#     'Barbara': 19,
#     'Barney': 10,
#     'Baron': 18,
#     'Barrett': 14,
#     'Barry': 17,
#     'Bart': 17,
#     'Bartholome': 19,
#     'Barton': 26,
#     'Baylee': 14,
#     'Beatrice': 20,
#     'Beau': 16,
#     'Beaulah': 14,
#     'Bell': 17,
#     'Bella': 14,
#     'Belle': 12,
#     'Ben': 15,
#     'Benedict': 15,
#     'Benjamin': 18,
#     'Bennett': 18,
#     'Bennie': 12,
#     'Benny': 17,
#     'Benton': 17,
#     'Berenice': 20,
#     'Bernadette': 15,
#     'Bernadine': 23,
#     'Bernard': 15,
#     'Bernardo': 11,
#     'Berneice': 15,
#     'Bernhard': 21,
#     'Bernice': 14,
#     'Bernie': 19,
#     'Berniece': 19,
#     'Bernita': 19,
#     'Berry': 22,
#     'Bert': 11,
#     'Berta': 14,
#     'Bertha': 20,
#     'Bertram': 19,
#     'Bertrand': 13,
#     'Beryl': 13,
#     'Bessie': 20,
#     'Beth': 24,
#     'Bethany': 18,
#     'Bethel': 22,
#     'Betsy': 20,
#     'Bette': 8,
#     'Bettie': 19,
#     'Betty': 18,
#     'Bettye': 14,
#     'Beulah': 15,
#     'Beverly': 17,
#     'Bianka': 10,
#     'Bill': 13,
#     'Billie': 13,
#     'Billy': 8,
#     'Birdie': 22,
#     'Blair': 19,
#     'Blaise': 14,
#     'Blake': 16,
#     'Blanca': 21,
#     'Blanche': 19,
#     'Blaze': 23,
#     'Bo': 14,
#     'Bobbie': 23,
#     'Bobby': 16,
#     'Bonita': 20,
#     'Bonnie': 17,
#     'Boris': 15,
#     'Boyd': 15,
#     'Brad': 17,
#     'Braden': 15,
#     'Bradford': 13,
#     'Bradley': 17,
#     'Bradly': 18,
#     'Brady': 20,
#     'Braeden': 25,
#     'Brain': 12,
#     'Brandi': 22,
#     'Brando': 18,
#     'Brandon': 18,
#     'Brandt': 16,
#     'Brandy': 22,
#     'Brandyn': 14,
#     'Brannon': 15,
#     'Branson': 18,
#     'Brant': 13,
#     'Braulio': 15,
#     'Braxton': 14,
#     'Brayan': 18,
#     'Breana': 22,
#     'Breanna': 20,
#     'Breanne': 20,
#     'Brenda': 11,
#     'Brendan': 14,
#     'Brenden': 20,
#     'Brendon': 12,
#     'Brenna': 16,
#     'Brennan': 11,
#     'Brennon': 27,
#     'Brent': 24,
#     'Bret': 27,
#     'Brett': 14,
#     'Bria': 10,
#     'Brian': 18,
#     'Briana': 15,
#     'Brianne': 16,
#     'Brice': 17,
#     'Bridget': 28,
#     'Bridgette': 26,
#     'Bridie': 21,
#     'Brielle': 15,
#     'Brigitte': 15,
#     'Brionna': 18,
#     'Brisa': 22,
#     'Britney': 16,
#     'Brittany': 14,
#     'Brock': 24,
#     'Broderick': 21,
#     'Brody': 14,
#     'Brook': 24,
#     'Brooke': 25,
#     'Brooklyn': 11,
#     'Brooks': 21,
#     'Brown': 13,
#     'Bruce': 15,
#     'Bryana': 18,
#     'Bryce': 20,
#     'Brycen': 21,
#     'Bryon': 14,
#     'Buck': 10,
#     'Bud': 8,
#     'Buddy': 21,
#     'Buford': 18,
#     'Bulah': 21,
#     'Burdette': 19,
#     'Burley': 15,
#     'Burnice': 14,
#     'Buster': 29,
#     'Cade': 13,
#     'Caden': 17,
#     'Caesar': 14,
#     'Caitlyn': 15,
#     'Cale': 15,
#     'Caleb': 22,
#     'Caleigh': 22,
#     'Cali': 25,
#     'Calista': 16,
#     'Callie': 17,
#     'Camden': 20,
#     'Cameron': 26,
#     'Camila': 15,
#     'Camilla': 15,
#     'Camille': 19,
#     'Camren': 20,
#     'Camron': 17,
#     'Camryn': 25,
#     'Camylle': 17,
#     'Candace': 16,
#     'Candelario': 23,
#     'Candice': 16,
#     'Candida': 16,
#     'Candido': 9,
#     'Cara': 20,
#     'Carey': 17,
#     'Carissa': 21,
#     'Carlee': 19,
#     'Carleton': 16,
#     'Carley': 22,
#     'Carli': 14,
#     'Carlie': 14,
#     'Carlo': 14,
#     'Carlos': 19,
#     'Carlotta': 15,
#     'Carmel': 15,
#     'Carmela': 8,
#     'Carmella': 20,
#     'Carmelo': 16,
#     'Carmen': 20,
#     'Carmine': 21,
#     'Carol': 20,
#     'Carolanne': 10,
#     'Carole': 17,
#     'Carolina': 19,
#     'Caroline': 16,
#     'Carolyn': 21,
#     'Carolyne': 19,
#     'Carrie': 18,
#     'Carroll': 21,
#     'Carson': 16,
#     'Carter': 22,
#     'Cary': 12,
#     'Casandra': 11,
#     'Casey': 14,
#     'Casimer': 24,
#     'Casimir': 12,
#     'Casper': 16,
#     'Cassandra': 16,
#     'Cassandre': 25,
#     'Cassidy': 12,
#     'Cassie': 13,
#     'Catalina': 16,
#     'Caterina': 16,
#     'Catharine': 17,
#     'Catherine': 18,
#     'Cathrine': 15,
#     'Cathryn': 13,
#     'Cathy': 18,
#     'Cayla': 15,
#     'Ceasar': 17,
#     'Cecelia': 14,
#     'Cecil': 13,
#     'Cecile': 26,
#     'Cecilia': 18,
#     'Cedrick': 17,
#     'Celestine': 11,
#     'Celestino': 14,
#     'Celia': 19,
#     'Celine': 16,
#     'Cesar': 21,
#     'Chad': 16,
#     'Chadd': 17,
#     'Chadrick': 17,
#     'Chaim': 15,
#     'Chance': 15,
#     'Chandler': 21,
#     'Chanel': 22,
#     'Chanelle': 13,
#     'Charity': 13,
#     'Charlene': 18,
#     'Charles': 15,
#     'Charley': 16,
#     'Charlie': 24,
#     'Charlotte': 20,
#     'Chase': 14,
#     'Chasity': 20,
#     'Chauncey': 16,
#     'Chaya': 20,
#     'Chaz': 21,
#     'Chelsea': 18,
#     'Chelsey': 17,
#     'Chelsie': 18,
#     'Chesley': 16,
#     'Chester': 13,
#     'Chet': 20,
#     'Cheyanne': 15,
#     'Cheyenne': 19,
#     'Chloe': 13,
#     'Chris': 15,
#     'Christ': 19,
#     'Christa': 21,
#     'Christelle': 12,
#     'Christian': 15,
#     'Christiana': 13,
#     'Christina': 14,
#     'Christine': 15,
#     'Christop': 15,
#     'Christophe': 15,
#     'Christopher': 17,
#     'Christy': 17,
#     'Chyna': 18,
#     'Ciara': 14,
#     'Cicero': 17,
#     'Cielo': 23,
#     'Cierra': 17,
#     'Cindy': 13,
#     'Citlalli': 17,
#     'Clair': 20,
#     'Claire': 22,
#     'Clara': 18,
#     'Clarabelle': 9,
#     'Clare': 18,
#     'Clarissa': 20,
#     'Clark': 13,
#     'Claud': 20,
#     'Claude': 23,
#     'Claudia': 12,
#     'Claudie': 24,
#     'Claudine': 23,
#     'Clay': 16,
#     'Clemens': 13,
#     'Clement': 14,
#     'Clementina': 24,
#     'Clementine': 18,
#     'Clemmie': 18,
#     'Cleo': 17,
#     'Cleora': 25,
#     'Cleta': 20,
#     'Cletus': 16,
#     'Cleve': 19,
#     'Cleveland': 14,
#     'Clifford': 22,
#     'Clifton': 12,
#     'Clint': 18,
#     'Clinton': 13,
#     'Clotilde': 18,
#     'Clovis': 17,
#     'Cloyd': 17,
#     'Clyde': 9,
#     'Coby': 17,
#     'Cody': 18,
#     'Colby': 21,
#     'Cole': 13,
#     'Coleman': 16,
#     'Colin': 20,
#     'Colleen': 20,
#     'Collin': 20,
#     'Colt': 13,
#     'Colten': 12,
#     'Colton': 13,
#     'Columbus': 25,
#     'Concepcion': 23,
#     'Conner': 16,
#     'Connie': 8,
#     'Connor': 20,
#     'Conor': 9,
#     'Conrad': 22,
#     'Constance': 19,
#     'Constantin': 16,
#     'Consuelo': 16,
#     'Cooper': 18,
#     'Cora': 13,
#     'Coralie': 17,
#     'Corbin': 20,
#     'Cordelia': 21,
#     'Cordell': 14,
#     'Cordia': 19,
#     'Cordie': 23,
#     'Corene': 21,
#     'Corine': 18,
#     'Cornelius': 21,
#     'Cornell': 18,
#     'Corrine': 15,
#     'Cortez': 19,
#     'Cortney': 16,
#     'Cory': 16,
#     'Coty': 18,
#     'Courtney': 22,
#     'Coy': 17,
#     'Craig': 23,
#     'Crawford': 19,
#     'Creola': 20,
#     'Cristal': 21,
#     'Cristian': 16,
#     'Cristina': 20,
#     'Cristobal': 20,
#     'Cristopher': 9,
#     'Cruz': 13,
#     'Crystal': 22,
#     'Crystel': 18,
#     'Cullen': 19,
#     'Curt': 25,
#     'Curtis': 13,
#     'Cydney': 11,
#     'Cynthia': 14,
#     'Cyril': 16,
#     'Cyrus': 15,
#     "D'angelo": 21,
#     'Dagmar': 13,
#     'Dahlia': 12,
#     'Daija': 19,
#     'Daisha': 18,
#     'Daisy': 20,
#     'Dakota': 15,
#     'Dale': 21,
#     'Dallas': 13,
#     'Dallin': 13,
#     'Dalton': 17,
#     'Damaris': 12,
#     'Dameon': 16,
#     'Damian': 16,
#     'Damien': 24,
#     'Damion': 14,
#     'Damon': 7,
#     'Dan': 15,
#     'Dana': 13,
#     'Dandre': 18,
#     'Dane': 15,
#     'Dangelo': 15,
#     'Danial': 18,
#     'Daniela': 16,
#     'Daniella': 11,
#     'Danielle': 13,
#     'Danika': 12,
#     'Dannie': 16,
#     'Danny': 12,
#     'Dante': 17,
#     'Danyka': 17,
#     'Daphne': 18,
#     'Daphnee': 15,
#     'Daphney': 10,
#     'Darby': 9,
#     'Daren': 18,
#     'Darian': 20,
#     'Dariana': 17,
#     'Darien': 20,
#     'Dario': 23,
#     'Darion': 14,
#     'Darius': 15,
#     'Darlene': 18,
#     'Daron': 12,
#     'Darrel': 16,
#     'Darrell': 16,
#     'Darren': 11,
#     'Darrick': 17,
#     'Darrin': 20,
#     'Darrion': 11,
#     'Darron': 18,
#     'Darryl': 19,
#     'Darwin': 18,
#     'Daryl': 19,
#     'Dashawn': 17,
#     'Dasia': 17,
#     'Dave': 13,
#     'David': 21,
#     'Davin': 16,
#     'Davion': 12,
#     'Davon': 18,
#     'Davonte': 14,
#     'Dawn': 14,
#     'Dawson': 13,
#     'Dax': 20,
#     'Dayana': 15,
#     'Dayna': 23,
#     'Dayne': 11,
#     'Dayton': 8,
#     'Dean': 19,
#     'Deangelo': 13,
#     'Deanna': 17,
#     'Deborah': 19,
#     'Declan': 15,
#     'Dedric': 18,
#     'Dedrick': 19,
#     'Dee': 18,
#     'Deion': 23,
#     'Deja': 15,
#     'Dejah': 19,
#     'Dejon': 22,
#     'Dejuan': 10,
#     'Delaney': 19,
#     'Delbert': 10,
#     'Delfina': 12,
#     'Delia': 22,
#     'Delilah': 22,
#     'Dell': 17,
#     'Della': 19,
#     'Delmer': 16,
#     'Delores': 12,
#     'Delpha': 21,
#     'Delphia': 14,
#     'Delphine': 17,
#     'Delta': 18,
#     'Demarco': 18,
#     'Demarcus': 19,
#     'Demario': 16,
#     'Demetris': 17,
#     'Demetrius': 20,
#     'Demond': 16,
#     'Dena': 17,
#     'Denis': 24,
#     'Dennis': 17,
#     'Deon': 26,
#     'Deondre': 15,
#     'Deontae': 13,
#     'Deonte': 21,
#     'Dereck': 16,
#     'Derek': 23,
#     'Derick': 15,
#     'Deron': 17,
#     'Derrick': 16,
#     'Deshaun': 9,
#     'Deshawn': 11,
#     'Desiree': 13,
#     'Desmond': 12,
#     'Dessie': 20,
#     'Destany': 20,
#     'Destin': 26,
#     'Destinee': 18,
#     'Destiney': 14,
#     'Destini': 21,
#     'Destiny': 12,
#     'Devan': 19,
#     'Devante': 23,
#     'Deven': 20,
#     'Devin': 18,
#     'Devon': 20,
#     'Devonte': 19,
#     'Devyn': 13,
#     'Dewayne': 18,
#     'Dewitt': 12,
#     'Dexter': 22,
#     'Diamond': 17,
#     'Diana': 18,
#     'Dianna': 17,
#     'Diego': 13,
#     'Dillan': 20,
#     'Dillon': 17,
#     'Dimitri': 13,
#     'Dina': 25,
#     'Dino': 21,
#     'Dion': 18,
#     'Dixie': 17,
#     'Dock': 15,
#     'Dolly': 23,
#     'Dolores': 20,
#     'Domenic': 18,
#     'Domenica': 16,
#     'Domenick': 15,
#     'Domenico': 15,
#     'Domingo': 14,
#     'Dominic': 22,
#     'Dominique': 16,
#     'Don': 17,
#     'Donald': 17,
#     'Donato': 13,
#     'Donavon': 20,
#     'Donna': 22,
#     'Donnell': 14,
#     'Donnie': 14,
#     'Donny': 11,
#     'Dora': 16,
#     'Dorcas': 14,
#     'Dorian': 15,
#     'Doris': 15,
#     'Dorothea': 10,
#     'Dorothy': 9,
#     'Dorris': 18,
#     'Dortha': 15,
#     'Dorthy': 16,
#     'Doug': 20,
#     'Douglas': 15,
#     'Dovie': 16,
#     'Doyle': 18,
#     'Drake': 12,
#     'Drew': 22,
#     'Duane': 19,
#     'Dudley': 9,
#     'Dulce': 13,
#     'Duncan': 14,
#     'Durward': 16,
#     'Dustin': 21,
#     'Dusty': 23,
#     'Dwight': 20,
#     'Dylan': 10,
#     'Earl': 15,
#     'Earlene': 26,
#     'Earline': 21,
#     'Earnest': 16,
#     'Earnestine': 15,
#     'Easter': 19,
#     'Easton': 21,
#     'Ebba': 8,
#     'Ebony': 8,
#     'Ed': 18,
#     'Eda': 20,
#     'Edd': 26,
#     'Eddie': 21,
#     'Eden': 19,
#     'Edgar': 16,
#     'Edgardo': 14,
#     'Edison': 14,
#     'Edmond': 14,
#     'Edmund': 17,
#     'Edna': 26,
#     'Eduardo': 24,
#     'Edward': 18,
#     'Edwardo': 15,
#     'Edwin': 13,
#     'Edwina': 21,
#     'Edyth': 14,
#     'Edythe': 13,
#     'Effie': 24,
#     'Efrain': 19,
#     'Efren': 16,
#     'Eileen': 19,
#     'Einar': 16,
#     'Eino': 21,
#     'Eladio': 13,
#     'Elaina': 12,
#     'Elbert': 19,
#     'Elda': 11,
#     'Eldon': 7,
#     'Eldora': 15,
#     'Eldred': 16,
#     'Eldridge': 16,
#     'Eleanora': 17,
#     'Eleanore': 17,
#     'Eleazar': 18,
#     'Electa': 15,
#     'Elena': 18,
#     'Elenor': 27,
#     'Elenora': 20,
#     'Eleonore': 20,
#     'Elfrieda': 9,
#     'Eli': 14,
#     'Elian': 16,
#     'Eliane': 17,
#     'Elias': 21,
#     'Eliezer': 24,
#     'Elijah': 18,
#     'Elinor': 16,
#     'Elinore': 19,
#     'Elisa': 16,
#     'Elisabeth': 14,
#     'Elise': 15,
#     'Eliseo': 11,
#     'Elisha': 14,
#     'Elissa': 14,
#     'Eliza': 17,
#     'Elizabeth': 17,
#     'Ella': 13,
#     'Ellen': 21,
#     'Ellie': 13,
#     'Elliot': 10,
#     'Elliott': 12,
#     'Ellis': 11,
#     'Ellsworth': 19,
#     'Elmer': 13,
#     'Elmira': 19,
#     'Elmo': 19,
#     'Elmore': 17,
#     'Elna': 22,
#     'Elnora': 15,
#     'Elody': 15,
#     'Eloisa': 17,
#     'Eloise': 11,
#     'Elouise': 25,
#     'Eloy': 16,
#     'Elroy': 12,
#     'Elsa': 17,
#     'Else': 27,
#     'Elsie': 22,
#     'Elta': 16,
#     'Elton': 18,
#     'Elva': 26,
#     'Elvera': 15,
#     'Elvie': 10,
#     'Elvis': 12,
#     'Elwin': 18,
#     'Elwyn': 15,
#     'Elyse': 32,
#     'Elyssa': 15,
#     'Elza': 15,
#     'Emanuel': 13,
#     'Emelia': 19,
#     'Emelie': 18,
#     'Emely': 12,
#     'Emerald': 14,
#     'Emerson': 16,
#     'Emery': 13,
#     'Emie': 14,
#     'Emil': 23,
#     'Emile': 26,
#     'Emilia': 21,
#     'Emiliano': 21,
#     'Emilie': 18,
#     'Emilio': 21,
#     'Emily': 17,
#     'Emma': 12,
#     'Emmalee': 23,
#     'Emmanuel': 17,
#     'Emmanuelle': 19,
#     'Emmet': 23,
#     'Emmett': 8,
#     'Emmie': 13,
#     'Emmitt': 18,
#     'Emmy': 15,
#     'Emory': 16,
#     'Ena': 13,
#     'Enid': 21,
#     'Enoch': 17,
#     'Enola': 22,
#     'Enos': 20,
#     'Enrico': 14,
#     'Enrique': 19,
#     'Ephraim': 16,
#     'Era': 15,
#     'Eriberto': 20,
#     'Eric': 16,
#     'Erica': 18,
#     'Erich': 18,
#     'Erick': 13,
#     'Ericka': 15,
#     'Erik': 18,
#     'Erika': 18,
#     'Erin': 19,
#     'Erling': 13,
#     'Erna': 17,
#     'Ernest': 24,
#     'Ernestina': 17,
#     'Ernestine': 13,
#     'Ernesto': 14,
#     'Ernie': 13,
#     'Ervin': 7,
#     'Erwin': 16,
#     'Eryn': 12,
#     'Esmeralda': 19,
#     'Esperanza': 16,
#     'Esta': 9,
#     'Esteban': 21,
#     ...},
#    'ordering': True,
#    'n_missing': 0,
#    'n': 50000,
#    'p_missing': 0.0,
#    'count': 50000,
#    'memory_size': 400128,
#    'imbalance': 0.0037495148747055396,
#    'first_rows': {'0': 'Bernadette',
#     '1': 'Camryn',
#     '2': 'Larue',
#     '3': 'Arch',
#     '4': 'Larue'},
#    'chi_squared': {'statistic': 2967.2224800000004,
#     'pvalue': 0.6892321893385115},
#    'max_length': 11,
#    'mean_length': 5.96202,
#    'median_length': 10,
#    'min_length': 2,
#    'length_histogram': {'6': 13958,
#     '5': 11390,
#     '7': 9690,
#     '4': 6089,
#     '8': 4725,
#     '9': 1792,
#     '3': 1684,
#     '10': 552,
#     '2': 67,
#     '11': 53},
#    'histogram_length': {'counts': [67,
#      1684,
#      6089,
#      11390,
#      13958,
#      9690,
#      4725,
#      1792,
#      552,
#      53],
#     'bin_edges': [2.0, 2.9, 3.8, 4.7, 5.6, 6.5, 7.4, 8.3, 9.2, 10.1, 11.0]},
#    'n_characters_distinct': 53,
#    'n_characters': 298101,
#    'character_counts': {'a': 36134,
#     'e': 35083,
#     'n': 24740,
#     'i': 22580,
#     'l': 20608,
#     'r': 20361,
#     'o': 15279,
#     't': 10203,
#     's': 9650,
#     'y': 9178,
#     'd': 8340,
#     'h': 5966,
#     'u': 5278,
#     'm': 5150,
#     'A': 4881,
#     'c': 4858,
#     'M': 4331,
#     'J': 3927,
#     'C': 3757,
#     'E': 3348,
#     'D': 3091,
#     'L': 3067,
#     'R': 2788,
#     'K': 2720,
#     'v': 2695,
#     'b': 2546,
#     'S': 2476,
#     'B': 2422,
#     'g': 2319,
#     'T': 1874,
#     'G': 1855,
#     'k': 1796,
#     'H': 1539,
#     'N': 1292,
#     'F': 1261,
#     'f': 1214,
#     'w': 1069,
#     'p': 1008,
#     'V': 988,
#     'O': 952,
#     'z': 937,
#     'W': 879,
#     'P': 862,
#     'I': 725,
#     'x': 564,
#     'Z': 452,
#     'q': 285,
#     'j': 239,
#     'Y': 175,
#     'U': 159,
#     'Q': 126,
#     'X': 53,
#     "'": 21},
#    'category_alias_values': {'a': 'Lowercase_Letter',
#     'e': 'Lowercase_Letter',
#     'n': 'Lowercase_Letter',
#     'i': 'Lowercase_Letter',
#     'l': 'Lowercase_Letter',
#     'r': 'Lowercase_Letter',
#     'o': 'Lowercase_Letter',
#     't': 'Lowercase_Letter',
#     's': 'Lowercase_Letter',
#     'y': 'Lowercase_Letter',
#     'd': 'Lowercase_Letter',
#     'h': 'Lowercase_Letter',
#     'u': 'Lowercase_Letter',
#     'm': 'Lowercase_Letter',
#     'A': 'Uppercase_Letter',
#     'c': 'Lowercase_Letter',
#     'M': 'Uppercase_Letter',
#     'J': 'Uppercase_Letter',
#     'C': 'Uppercase_Letter',
#     'E': 'Uppercase_Letter',
#     'D': 'Uppercase_Letter',
#     'L': 'Uppercase_Letter',
#     'R': 'Uppercase_Letter',
#     'K': 'Uppercase_Letter',
#     'v': 'Lowercase_Letter',
#     'b': 'Lowercase_Letter',
#     'S': 'Uppercase_Letter',
#     'B': 'Uppercase_Letter',
#     'g': 'Lowercase_Letter',
#     'T': 'Uppercase_Letter',
#     'G': 'Uppercase_Letter',
#     'k': 'Lowercase_Letter',
#     'H': 'Uppercase_Letter',
#     'N': 'Uppercase_Letter',
#     'F': 'Uppercase_Letter',
#     'f': 'Lowercase_Letter',
#     'w': 'Lowercase_Letter',
#     'p': 'Lowercase_Letter',
#     'V': 'Uppercase_Letter',
#     'O': 'Uppercase_Letter',
#     'z': 'Lowercase_Letter',
#     'W': 'Uppercase_Letter',
#     'P': 'Uppercase_Letter',
#     'I': 'Uppercase_Letter',
#     'x': 'Lowercase_Letter',
#     'Z': 'Uppercase_Letter',
#     'q': 'Lowercase_Letter',
#     'j': 'Lowercase_Letter',
#     'Y': 'Uppercase_Letter',
#     'U': 'Uppercase_Letter',
#     'Q': 'Uppercase_Letter',
#     'X': 'Uppercase_Letter',
#     "'": 'Other_Punctuation'},
#    'block_alias_values': {'a': 'ASCII',
#     'e': 'ASCII',
#     'n': 'ASCII',
#     'i': 'ASCII',
#     'l': 'ASCII',
#     'r': 'ASCII',
#     'o': 'ASCII',
#     't': 'ASCII',
#     's': 'ASCII',
#     'y': 'ASCII',
#     'd': 'ASCII',
#     'h': 'ASCII',
#     'u': 'ASCII',
#     'm': 'ASCII',
#     'A': 'ASCII',
#     'c': 'ASCII',
#     'M': 'ASCII',
#     'J': 'ASCII',
#     'C': 'ASCII',
#     'E': 'ASCII',
#     'D': 'ASCII',
#     'L': 'ASCII',
#     'R': 'ASCII',
#     'K': 'ASCII',
#     'v': 'ASCII',
#     'b': 'ASCII',
#     'S': 'ASCII',
#     'B': 'ASCII',
#     'g': 'ASCII',
#     'T': 'ASCII',
#     'G': 'ASCII',
#     'k': 'ASCII',
#     'H': 'ASCII',
#     'N': 'ASCII',
#     'F': 'ASCII',
#     'f': 'ASCII',
#     'w': 'ASCII',
#     'p': 'ASCII',
#     'V': 'ASCII',
#     'O': 'ASCII',
#     'z': 'ASCII',
#     'W': 'ASCII',
#     'P': 'ASCII',
#     'I': 'ASCII',
#     'x': 'ASCII',
#     'Z': 'ASCII',
#     'q': 'ASCII',
#     'j': 'ASCII',
#     'Y': 'ASCII',
#     'U': 'ASCII',
#     'Q': 'ASCII',
#     'X': 'ASCII',
#     "'": 'ASCII'},
#    'block_alias_counts': {'ASCII': 298101},
#    'n_block_alias': 1,
#    'block_alias_char_counts': {'ASCII': {'a': 36134,
#      'e': 35083,
#      'n': 24740,
#      'i': 22580,
#      'l': 20608,
#      'r': 20361,
#      'o': 15279,
#      't': 10203,
#      's': 9650,
#      'y': 9178,
#      'd': 8340,
#      'h': 5966,
#      'u': 5278,
#      'm': 5150,
#      'A': 4881,
#      'c': 4858,
#      'M': 4331,
#      'J': 3927,
#      'C': 3757,
#      'E': 3348,
#      'D': 3091,
#      'L': 3067,
#      'R': 2788,
#      'K': 2720,
#      'v': 2695,
#      'b': 2546,
#      'S': 2476,
#      'B': 2422,
#      'g': 2319,
#      'T': 1874,
#      'G': 1855,
#      'k': 1796,
#      'H': 1539,
#      'N': 1292,
#      'F': 1261,
#      'f': 1214,
#      'w': 1069,
#      'p': 1008,
#      'V': 988,
#      'O': 952,
#      'z': 937,
#      'W': 879,
#      'P': 862,
#      'I': 725,
#      'x': 564,
#      'Z': 452,
#      'q': 285,
#      'j': 239,
#      'Y': 175,
#      'U': 159,
#      'Q': 126,
#      'X': 53,
#      "'": 21}},
#    'script_counts': {'Latin': 298080, 'Common': 21},
#    'n_scripts': 2,
#    'script_char_counts': {'Latin': {'a': 36134,
#      'e': 35083,
#      'n': 24740,
#      'i': 22580,
#      'l': 20608,
#      'r': 20361,
#      'o': 15279,
#      't': 10203,
#      's': 9650,
#      'y': 9178,
#      'd': 8340,
#      'h': 5966,
#      'u': 5278,
#      'm': 5150,
#      'A': 4881,
#      'c': 4858,
#      'M': 4331,
#      'J': 3927,
#      'C': 3757,
#      'E': 3348,
#      'D': 3091,
#      'L': 3067,
#      'R': 2788,
#      'K': 2720,
#      'v': 2695,
#      'b': 2546,
#      'S': 2476,
#      'B': 2422,
#      'g': 2319,
#      'T': 1874,
#      'G': 1855,
#      'k': 1796,
#      'H': 1539,
#      'N': 1292,
#      'F': 1261,
#      'f': 1214,
#      'w': 1069,
#      'p': 1008,
#      'V': 988,
#      'O': 952,
#      'z': 937,
#      'W': 879,
#      'P': 862,
#      'I': 725,
#      'x': 564,
#      'Z': 452,
#      'q': 285,
#      'j': 239,
#      'Y': 175,
#      'U': 159,
#      'Q': 126,
#      'X': 53},
#     'Common': {"'": 21}},
#    'category_alias_counts': {'Lowercase Letter': 248080,
#     'Uppercase Letter': 50000,
#     'Other Punctuation': 21},
#    'n_category': 3,
#    'category_alias_char_counts': {'Lowercase_Letter': {'a': 36134,
#      'e': 35083,
#      'n': 24740,
#      'i': 22580,
#      'l': 20608,
#      'r': 20361,
#      'o': 15279,
#      't': 10203,
#      's': 9650,
#      'y': 9178,
#      'd': 8340,
#      'h': 5966,
#      'u': 5278,
#      'm': 5150,
#      'c': 4858,
#      'v': 2695,
#      'b': 2546,
#      'g': 2319,
#      'k': 1796,
#      'f': 1214,
#      'w': 1069,
#      'p': 1008,
#      'z': 937,
#      'x': 564,
#      'q': 285,
#      'j': 239},
#     'Uppercase_Letter': {'A': 4881,
#      'M': 4331,
#      'J': 3927,
#      'C': 3757,
#      'E': 3348,
#      'D': 3091,
#      'L': 3067,
#      'R': 2788,
#      'K': 2720,
#      'S': 2476,
#      'B': 2422,
#      'T': 1874,
#      'G': 1855,
#      'H': 1539,
#      'N': 1292,
#      'F': 1261,
#      'V': 988,
#      'O': 952,
#      'W': 879,
#      'P': 862,
#      'I': 725,
#      'Z': 452,
#      'Y': 175,
#      'U': 159,
#      'Q': 126,
#      'X': 53},
#     'Other_Punctuation': {"'": 21}},
#    'word_counts': {'sarai': 33,
#     'elyse': 32,
#     'eva': 31,
#     'anabel': 31,
#     'nayeli': 30,
#     'luna': 29,
#     'buster': 29,
#     'bridget': 28,
#     'veronica': 28,
#     'jena': 28,
#     'tyler': 28,
#     'wyman': 28,
#     'terrell': 28,
#     'jake': 28,
#     'golda': 28,
#     'ari': 28,
#     'lazaro': 28,
#     'brennon': 27,
#     'else': 27,
#     'reginald': 27,
#     'marc': 27,
#     'tremayne': 27,
#     'elenor': 27,
#     'yasmin': 27,
#     'kelvin': 27,
#     'alvina': 27,
#     'zechariah': 27,
#     'bret': 27,
#     'glennie': 27,
#     'alek': 26,
#     'rowan': 26,
#     'edna': 26,
#     'barton': 26,
#     'cameron': 26,
#     'destin': 26,
#     'deon': 26,
#     'elva': 26,
#     'marcia': 26,
#     'verner': 26,
#     'earlene': 26,
#     'etha': 26,
#     'tressie': 26,
#     'alyce': 26,
#     'edd': 26,
#     'bridgette': 26,
#     'emile': 26,
#     'mara': 26,
#     'stevie': 26,
#     'lavern': 26,
#     'rosalia': 26,
#     'tyrell': 26,
#     'maci': 26,
#     'ola': 26,
#     'roselyn': 26,
#     'ashlee': 26,
#     'haylee': 26,
#     'cecile': 26,
#     'margret': 26,
#     'genoveva': 25,
#     'jaleel': 25,
#     'florida': 25,
#     'saul': 25,
#     'jaime': 25,
#     'frida': 25,
#     'mariam': 25,
#     'herminio': 25,
#     'lolita': 25,
#     'genevieve': 25,
#     'mustafa': 25,
#     'dina': 25,
#     'cali': 25,
#     'johathan': 25,
#     'orrin': 25,
#     'cassandre': 25,
#     'esther': 25,
#     'isabel': 25,
#     'rachael': 25,
#     'curt': 25,
#     'brooke': 25,
#     'nya': 25,
#     'jimmie': 25,
#     'ryan': 25,
#     'camryn': 25,
#     'watson': 25,
#     'thalia': 25,
#     'stanley': 25,
#     'braeden': 25,
#     'zoila': 25,
#     'tianna': 25,
#     'milton': 25,
#     'shaylee': 25,
#     'cleora': 25,
#     'elouise': 25,
#     'angeline': 25,
#     'julien': 25,
#     'green': 25,
#     'garry': 25,
#     'columbus': 25,
#     'jaylon': 25,
#     'rico': 24,
#     'janice': 24,
#     'henriette': 24,
#     'faustino': 24,
#     'marty': 24,
#     'luz': 24,
#     'ulices': 24,
#     'shawn': 24,
#     'damien': 24,
#     'maye': 24,
#     'mozelle': 24,
#     'eduardo': 24,
#     'kendra': 24,
#     'denis': 24,
#     'gabrielle': 24,
#     'clementina': 24,
#     'claudie': 24,
#     'jairo': 24,
#     'sadie': 24,
#     'josefina': 24,
#     'tod': 24,
#     'brook': 24,
#     'brock': 24,
#     'ewell': 24,
#     'felicita': 24,
#     'gino': 24,
#     'lourdes': 24,
#     'jovany': 24,
#     'torrey': 24,
#     'jalen': 24,
#     'abbigail': 24,
#     'casimer': 24,
#     'charlie': 24,
#     'katherine': 24,
#     'lorena': 24,
#     'hester': 24,
#     'beth': 24,
#     'grace': 24,
#     'stacey': 24,
#     'brent': 24,
#     'nichole': 24,
#     'samara': 24,
#     'anibal': 24,
#     'eliezer': 24,
#     'obie': 24,
#     'ernest': 24,
#     'melisa': 24,
#     'sydney': 24,
#     'alta': 24,
#     'jayson': 24,
#     'sister': 24,
#     'lawson': 24,
#     'lauryn': 24,
#     'marina': 24,
#     'effie': 24,
#     'joy': 23,
#     'pietro': 23,
#     'cielo': 23,
#     'sincere': 23,
#     'devante': 23,
#     'janet': 23,
#     'emmet': 23,
#     'evan': 23,
#     'hellen': 23,
#     'dayna': 23,
#     'concepcion': 23,
#     'amya': 23,
#     'kaelyn': 23,
#     'derek': 23,
#     'kellen': 23,
#     'laney': 23,
#     'roberta': 23,
#     'santa': 23,
#     'vivianne': 23,
#     'jaclyn': 23,
#     'blaze': 23,
#     'arianna': 23,
#     'zack': 23,
#     'rhoda': 23,
#     'rey': 23,
#     'harmon': 23,
#     'hugh': 23,
#     'kyla': 23,
#     'allison': 23,
#     'jettie': 23,
#     'mary': 23,
#     'rylee': 23,
#     'fritz': 23,
#     'modesta': 23,
#     'maritza': 23,
#     'furman': 23,
#     'claude': 23,
#     'wilfrid': 23,
#     'claudine': 23,
#     'lloyd': 23,
#     'lulu': 23,
#     'archibald': 23,
#     'eunice': 23,
#     'jolie': 23,
#     'jeremy': 23,
#     'zane': 23,
#     'montana': 23,
#     'angelita': 23,
#     'aaliyah': 23,
#     'dolly': 23,
#     'emil': 23,
#     'kennedi': 23,
#     'friedrich': 23,
#     'shany': 23,
#     'deion': 23,
#     'bobbie': 23,
#     'kallie': 23,
#     'amira': 23,
#     'theodora': 23,
#     'emmalee': 23,
#     'irving': 23,
#     'lewis': 23,
#     'kale': 23,
#     'rasheed': 23,
#     'evie': 23,
#     'jacky': 23,
#     'lorenzo': 23,
#     'candelario': 23,
#     'bernadine': 23,
#     'vesta': 23,
#     'cordie': 23,
#     'alysha': 23,
#     'alverta': 23,
#     'estrella': 23,
#     'hortense': 23,
#     'kylie': 23,
#     'dario': 23,
#     'dusty': 23,
#     'velma': 23,
#     'craig': 23,
#     'matilde': 23,
#     'maybelle': 23,
# ...
#     'n': 'Lowercase_Letter',
#     'r': 'Lowercase_Letter',
#     'i': 'Lowercase_Letter',
#     't': 'Lowercase_Letter',
#     'd': 'Lowercase_Letter',
#     'L': 'Uppercase_Letter',
#     'a': 'Lowercase_Letter',
#     'o': 'Lowercase_Letter',
#     'c': 'Lowercase_Letter',
#     'I': 'Uppercase_Letter',
#     'v': 'Lowercase_Letter',
#     'l': 'Lowercase_Letter',
#     '-': 'Dash_Punctuation',
#     'M': 'Uppercase_Letter',
#     'T': 'Uppercase_Letter',
#     'J': 'Uppercase_Letter',
#     'u': 'Lowercase_Letter',
#     'A': 'Uppercase_Letter',
#     'h': 'Lowercase_Letter',
#     'S': 'Uppercase_Letter'},
#    'block_alias_values': {'e': 'ASCII',
#     'n': 'ASCII',
#     'r': 'ASCII',
#     'i': 'ASCII',
#     't': 'ASCII',
#     'd': 'ASCII',
#     'L': 'ASCII',
#     'a': 'ASCII',
#     'o': 'ASCII',
#     'c': 'ASCII',
#     'I': 'ASCII',
#     'v': 'ASCII',
#     'l': 'ASCII',
#     '-': 'ASCII',
#     'M': 'ASCII',
#     'T': 'ASCII',
#     'J': 'ASCII',
#     'u': 'ASCII',
#     'A': 'ASCII',
#     'h': 'ASCII',
#     'S': 'ASCII'},
#    'block_alias_counts': {'ASCII': 336037},
#    'n_block_alias': 1,
#    'block_alias_char_counts': {'ASCII': {'e': 57336,
#      'n': 35852,
#      'r': 35676,
#      'i': 35674,
#      't': 21413,
#      'd': 14324,
#      'L': 14324,
#      'a': 14254,
#      'o': 14159,
#      'c': 14158,
#      'I': 7255,
#      'v': 7253,
#      'l': 7253,
#      '-': 7253,
#      'M': 7253,
#      'T': 7183,
#      'J': 7100,
#      'u': 7100,
#      'A': 7079,
#      'h': 7079,
#      'S': 7059}},
#    'script_counts': {'Latin': 328784, 'Common': 7253},
#    'n_scripts': 2,
#    'script_char_counts': {'Latin': {'e': 57336,
#      'n': 35852,
#      'r': 35676,
#      'i': 35674,
#      't': 21413,
#      'd': 14324,
#      'L': 14324,
#      'a': 14254,
#      'o': 14159,
#      'c': 14158,
#      'I': 7255,
#      'v': 7253,
#      'l': 7253,
#      'M': 7253,
#      'T': 7183,
#      'J': 7100,
#      'u': 7100,
#      'A': 7079,
#      'h': 7079,
#      'S': 7059},
#     'Common': {'-': 7253}},
#    'category_alias_counts': {'Lowercase Letter': 271531,
#     'Uppercase Letter': 57253,
#     'Dash Punctuation': 7253},
#    'n_category': 3,
#    'category_alias_char_counts': {'Lowercase_Letter': {'e': 57336,
#      'n': 35852,
#      'r': 35676,
#      'i': 35674,
#      't': 21413,
#      'd': 14324,
#      'a': 14254,
#      'o': 14159,
#      'c': 14158,
#      'v': 7253,
#      'l': 7253,
#      'u': 7100,
#      'h': 7079},
#     'Uppercase_Letter': {'L': 14324,
#      'I': 7255,
#      'M': 7253,
#      'T': 7183,
#      'J': 7100,
#      'A': 7079,
#      'S': 7059},
#     'Dash_Punctuation': {'-': 7253}},
#    'word_counts': {'intern': 7255,
#     'mid-level': 7253,
#     'trainee': 7183,
#     'junior': 7100,
#     'architect': 7079,
#     'lead': 7071,
#     'senior': 7059}},
#   'Technology': {'n_distinct': 24,
#    'p_distinct': 0.00048,
#    'is_unique': False,
#    'n_unique': 0,
#    'p_unique': 0.0,
#    'type': 'Categorical',
#    'hashable': True,
#    'value_counts_without_nan': {'Game Development': 3818,
#     'DevOps': 3808,
#     'Social Media Community Management': 2028,
#     'System Administration': 2014,
#     'Mulesoft': 1973,
#     'Development - Backend': 1965,
#     'Development - FullStack': 1961,
#     'Adobe Experience Manager': 1954,
#     'Data Engineer': 1951,
#     'Security': 1936,
#     'Development - CMS Frontend': 1934,
#     'Business Intelligence': 1934,
#     'Database Administration': 1933,
#     'Client Success': 1927,
#     'Design': 1906,
#     'QA Manual': 1902,
#     'Technical Writing': 1901,
#     'QA Automation': 1892,
#     'Sales': 1890,
#     'Development - Frontend': 1887,
#     'Development - CMS Backend': 1882,
#     'Business Analytics / Project Management': 1878,
#     'Salesforce': 1874,
#     'Security Compliance': 1852},
#    'value_counts_index_sorted': {'Adobe Experience Manager': 1954,
#     'Business Analytics / Project Management': 1878,
#     'Business Intelligence': 1934,
#     'Client Success': 1927,
#     'Data Engineer': 1951,
#     'Database Administration': 1933,
#     'Design': 1906,
#     'DevOps': 3808,
#     'Development - Backend': 1965,
#     'Development - CMS Backend': 1882,
#     'Development - CMS Frontend': 1934,
#     'Development - Frontend': 1887,
#     'Development - FullStack': 1961,
#     'Game Development': 3818,
#     'Mulesoft': 1973,
#     'QA Automation': 1892,
#     'QA Manual': 1902,
#     'Sales': 1890,
#     'Salesforce': 1874,
#     'Security': 1936,
#     'Security Compliance': 1852,
#     'Social Media Community Management': 2028,
#     'System Administration': 2014,
#     'Technical Writing': 1901},
#    'ordering': True,
#    'n_missing': 0,
#    'n': 50000,
#    'p_missing': 0.0,
#    'count': 50000,
#    'memory_size': 400128,
#    'imbalance': 0.00815097489577643,
#    'first_rows': {'0': 'Data Engineer',
#     '1': 'Data Engineer',
#     '2': 'Client Success',
#     '3': 'QA Manual',
#     '4': 'Social Media Community Management'},
#    'chi_squared': {'statistic': 3153.7350399999996, 'pvalue': 0.0},
#    'max_length': 39,
#    'mean_length': 17.12078,
#    'median_length': 23,
#    'min_length': 5,
#    'length_histogram': {'21': 5913,
#     '6': 5714,
#     '8': 3909,
#     '23': 3894,
#     '13': 3843,
#     '16': 3818,
#     '33': 2028,
#     '24': 1954,
#     '26': 1934,
#     '14': 1927,
#     '9': 1902,
#     '17': 1901,
#     '5': 1890,
#     '22': 1887,
#     '25': 1882,
#     '39': 1878,
#     '10': 1874,
#     '19': 1852},
#    'histogram_length': {'counts': [7604,
#      3909,
#      3776,
#      0,
#      5770,
#      3818,
#      1901,
#      1852,
#      5913,
#      5781,
#      3836,
#      1934,
#      0,
#      0,
#      2028,
#      0,
#      0,
#      1878],
#     'bin_edges': [5.0,
#      6.888888888888889,
#      8.777777777777779,
#      10.666666666666666,
#      12.555555555555555,
#      14.444444444444445,
#      16.333333333333332,
#      18.22222222222222,
#      20.11111111111111,
#      22.0,
#      23.88888888888889,
#      25.77777777777778,
#      27.666666666666664,
#      29.555555555555554,
#      31.444444444444443,
#      33.33333333333333,
#      35.22222222222222,
#      37.11111111111111,
#      39.0]},
#    'n_characters_distinct': 41,
#    'n_characters': 856039,
#    'character_counts': {'e': 115498,
#     'n': 73319,
#     ' ': 61702,
#     't': 58018,
#     'a': 54141,
#     'i': 46522,
#     'o': 38586,
#     'l': 38462,
#     's': 36513,
#     'm': 34932,
#     'c': 30650,
#     'r': 23068,
#     'D': 23045,
#     'p': 21061,
#     'S': 19298,
#     'u': 19283,
#     'v': 17255,
#     'd': 15597,
#     'M': 15579,
#     'g': 13552,
#     'A': 13465,
#     'y': 9708,
#     '-': 9629,
#     'C': 9623,
#     'B': 7659,
#     'k': 5808,
#     'F': 5782,
#     'E': 3905,
#     'b': 3887,
#     'f': 3847,
#     'G': 3818,
#     'O': 3808,
#     'Q': 3794,
#     'x': 1954,
#     'I': 1934,
#     'T': 1901,
#     'h': 1901,
#     'W': 1901,
#     '/': 1878,
#     'P': 1878,
#     'j': 1878},
#    'category_alias_values': {'e': 'Lowercase_Letter',
#     'n': 'Lowercase_Letter',
#     ' ': 'Space_Separator',
#     't': 'Lowercase_Letter',
#     'a': 'Lowercase_Letter',
#     'i': 'Lowercase_Letter',
#     'o': 'Lowercase_Letter',
#     'l': 'Lowercase_Letter',
#     's': 'Lowercase_Letter',
#     'm': 'Lowercase_Letter',
#     'c': 'Lowercase_Letter',
#     'r': 'Lowercase_Letter',
#     'D': 'Uppercase_Letter',
#     'p': 'Lowercase_Letter',
#     'S': 'Uppercase_Letter',
#     'u': 'Lowercase_Letter',
#     'v': 'Lowercase_Letter',
#     'd': 'Lowercase_Letter',
#     'M': 'Uppercase_Letter',
#     'g': 'Lowercase_Letter',
#     'A': 'Uppercase_Letter',
#     'y': 'Lowercase_Letter',
#     '-': 'Dash_Punctuation',
#     'C': 'Uppercase_Letter',
#     'B': 'Uppercase_Letter',
#     'k': 'Lowercase_Letter',
#     'F': 'Uppercase_Letter',
#     'E': 'Uppercase_Letter',
#     'b': 'Lowercase_Letter',
#     'f': 'Lowercase_Letter',
#     'G': 'Uppercase_Letter',
#     'O': 'Uppercase_Letter',
#     'Q': 'Uppercase_Letter',
#     'x': 'Lowercase_Letter',
#     'I': 'Uppercase_Letter',
#     'T': 'Uppercase_Letter',
#     'h': 'Lowercase_Letter',
#     'W': 'Uppercase_Letter',
#     '/': 'Other_Punctuation',
#     'P': 'Uppercase_Letter',
#     'j': 'Lowercase_Letter'},
#    'block_alias_values': {'e': 'ASCII',
#     'n': 'ASCII',
#     ' ': 'ASCII',
#     't': 'ASCII',
#     'a': 'ASCII',
#     'i': 'ASCII',
#     'o': 'ASCII',
#     'l': 'ASCII',
#     's': 'ASCII',
#     'm': 'ASCII',
#     'c': 'ASCII',
#     'r': 'ASCII',
#     'D': 'ASCII',
#     'p': 'ASCII',
#     'S': 'ASCII',
#     'u': 'ASCII',
#     'v': 'ASCII',
#     'd': 'ASCII',
#     'M': 'ASCII',
#     'g': 'ASCII',
#     'A': 'ASCII',
#     'y': 'ASCII',
#     '-': 'ASCII',
#     'C': 'ASCII',
#     'B': 'ASCII',
#     'k': 'ASCII',
#     'F': 'ASCII',
#     'E': 'ASCII',
#     'b': 'ASCII',
#     'f': 'ASCII',
#     'G': 'ASCII',
#     'O': 'ASCII',
#     'Q': 'ASCII',
#     'x': 'ASCII',
#     'I': 'ASCII',
#     'T': 'ASCII',
#     'h': 'ASCII',
#     'W': 'ASCII',
#     '/': 'ASCII',
#     'P': 'ASCII',
#     'j': 'ASCII'},
#    'block_alias_counts': {'ASCII': 856039},
#    'n_block_alias': 1,
#    'block_alias_char_counts': {'ASCII': {'e': 115498,
#      'n': 73319,
#      ' ': 61702,
#      't': 58018,
#      'a': 54141,
#      'i': 46522,
#      'o': 38586,
#      'l': 38462,
#      's': 36513,
#      'm': 34932,
#      'c': 30650,
#      'r': 23068,
#      'D': 23045,
#      'p': 21061,
#      'S': 19298,
#      'u': 19283,
#      'v': 17255,
#      'd': 15597,
#      'M': 15579,
#      'g': 13552,
#      'A': 13465,
#      'y': 9708,
#      '-': 9629,
#      'C': 9623,
#      'B': 7659,
#      'k': 5808,
#      'F': 5782,
#      'E': 3905,
#      'b': 3887,
#      'f': 3847,
#      'G': 3818,
#      'O': 3808,
#      'Q': 3794,
#      'x': 1954,
#      'I': 1934,
#      'T': 1901,
#      'h': 1901,
#      'W': 1901,
#      '/': 1878,
#      'P': 1878,
#      'j': 1878}},
#    'script_counts': {'Latin': 782830, 'Common': 73209},
#    'n_scripts': 2,
#    'script_char_counts': {'Latin': {'e': 115498,
#      'n': 73319,
#      't': 58018,
#      'a': 54141,
#      'i': 46522,
#      'o': 38586,
#      'l': 38462,
#      's': 36513,
#      'm': 34932,
#      'c': 30650,
#      'r': 23068,
#      'D': 23045,
#      'p': 21061,
#      'S': 19298,
#      'u': 19283,
#      'v': 17255,
#      'd': 15597,
#      'M': 15579,
#      'g': 13552,
#      'A': 13465,
#      'y': 9708,
#      'C': 9623,
#      'B': 7659,
#      'k': 5808,
#      'F': 5782,
#      'E': 3905,
#      'b': 3887,
#      'f': 3847,
#      'G': 3818,
#      'O': 3808,
#      'Q': 3794,
#      'x': 1954,
#      'I': 1934,
#      'T': 1901,
#      'h': 1901,
#      'W': 1901,
#      'P': 1878,
#      'j': 1878},
#     'Common': {' ': 61702, '-': 9629, '/': 1878}},
#    'category_alias_counts': {'Lowercase Letter': 665440,
#     'Uppercase Letter': 117390,
#     'Space Separator': 61702,
#     'Dash Punctuation': 9629,
#     'Other Punctuation': 1878},
#    'n_category': 5,
#    'category_alias_char_counts': {'Lowercase_Letter': {'e': 115498,
#      'n': 73319,
#      't': 58018,
#      'a': 54141,
#      'i': 46522,
#      'o': 38586,
#      'l': 38462,
#      's': 36513,
#      'm': 34932,
#      'c': 30650,
#      'r': 23068,
#      'p': 21061,
#      'u': 19283,
#      'v': 17255,
#      'd': 15597,
#      'g': 13552,
#      'y': 9708,
#      'k': 5808,
#      'b': 3887,
#      'f': 3847,
#      'x': 1954,
#      'h': 1901,
#      'j': 1878},
#     'Space_Separator': {' ': 61702},
#     'Uppercase_Letter': {'D': 23045,
#      'S': 19298,
#      'M': 15579,
#      'A': 13465,
#      'C': 9623,
#      'B': 7659,
#      'F': 5782,
#      'E': 3905,
#      'G': 3818,
#      'O': 3808,
#      'Q': 3794,
#      'I': 1934,
#      'T': 1901,
#      'W': 1901,
#      'P': 1878},
#     'Dash_Punctuation': {'-': 9629},
#     'Other_Punctuation': {'/': 1878}},
#    'word_counts': {'development': 13447,
#     '': 11507,
#     'administration': 3947,
#     'management': 3906,
#     'backend': 3847,
#     'frontend': 3821,
#     'game': 3818,
#     'cms': 3816,
#     'business': 3812,
#     'devops': 3808,
#     'qa': 3794,
#     'security': 3788,
#     'social': 2028,
#     'community': 2028,
#     'media': 2028,
#     'system': 2014,
#     'mulesoft': 1973,
#     'fullstack': 1961,
#     'experience': 1954,
#     'manager': 1954,
#     'adobe': 1954,
#     'data': 1951,
#     'engineer': 1951,
#     'intelligence': 1934,
#     'database': 1933,
#     'client': 1927,
#     'success': 1927,
#     'design': 1906,
#     'manual': 1902,
#     'technical': 1901,
#     'writing': 1901,
#     'automation': 1892,
#     'sales': 1890,
#     'analytics': 1878,
#     'project': 1878,
#     'salesforce': 1874,
#     'compliance': 1852}},
#   'Code Challenge Score': {'n_distinct': 11,
#    'p_distinct': 0.00022,
#    'is_unique': False,
#    'n_unique': 0,
#    'p_unique': 0.0,
#    'type': 'Numeric',
#    'hashable': True,
#    'value_counts_without_nan': {'3': 4678,
#     '8': 4619,
#     '1': 4590,
#     '10': 4588,
#     '2': 4579,
#     '4': 4521,
#     '9': 4519,
#     '7': 4506,
#     '0': 4502,
#     '5': 4479,
#     '6': 4419},
#    'value_counts_index_sorted': {'0': 4502,
#     '1': 4590,
#     '2': 4579,
#     '3': 4678,
#     '4': 4521,
#     '5': 4479,
#     '6': 4419,
#     '7': 4506,
#     '8': 4619,
#     '9': 4519,
#     '10': 4588},
#    'ordering': True,
#    'n_missing': 0,
#    'n': 50000,
#    'p_missing': 0.0,
#    'count': 50000,
#    'memory_size': 400128,
#    'n_negative': 0,
#    'p_negative': 0.0,
#    'n_infinite': 0,
#    'n_zeros': 4502,
#    'mean': 4.9964,
#    'std': 3.166895581567616,
#    'variance': 10.029227624552489,
#    'min': 0,
#    'max': 10,
#    'kurtosis': -1.2274682409922943,
#    'skewness': 0.007067893205398745,
#    'sum': 249820,
#    'mad': 3.0,
#    'chi_squared': {'statistic': 90941.97988, 'pvalue': 0.0},
#    'range': 10,
#    '5%': 0.0,
#    '25%': 2.0,
#    '50%': 5.0,
#    '75%': 8.0,
#    '95%': 10.0,
#    'iqr': 6.0,
#    'cv': 0.6338354778575807,
#    'p_zeros': 0.09004,
#    'p_infinite': 0.0,
#    'monotonic_increase': False,
#    'monotonic_decrease': False,
#    'monotonic_increase_strict': False,
#    'monotonic_decrease_strict': False,
#    'monotonic': 0,
#    'histogram': {'counts': [4502,
#      4590,
#      4579,
#      4678,
#      4521,
#      4479,
#      4419,
#      4506,
#      4619,
#      4519,
#      4588],
#     'bin_edges': [0.0,
#      0.9090909090909091,
#      1.8181818181818181,
#      2.727272727272727,
#      3.6363636363636362,
#      4.545454545454545,
#      5.454545454545454,
#      6.363636363636363,
#      7.2727272727272725,
#      8.181818181818182,
#      9.09090909090909,
#      10.0]}},
#   'Technical Interview Score': {'n_distinct': 11,
#    'p_distinct': 0.00022,
#    'is_unique': False,
#    'n_unique': 0,
#    'p_unique': 0.0,
#    'type': 'Numeric',
#    'hashable': True,
#    'value_counts_without_nan': {'9': 4597,
#     '1': 4588,
#     '7': 4578,
#     '4': 4578,
#     '8': 4555,
#     '10': 4539,
#     '0': 4539,
#     '3': 4528,
#     '5': 4527,
#     '2': 4500,
#     '6': 4471},
#    'value_counts_index_sorted': {'0': 4539,
#     '1': 4588,
#     '2': 4500,
#     '3': 4528,
#     '4': 4578,
#     '5': 4527,
#     '6': 4471,
#     '7': 4578,
#     '8': 4555,
#     '9': 4597,
#     '10': 4539},
#    'ordering': True,
#    'n_missing': 0,
#    'n': 50000,
#    'p_missing': 0.0,
#    'count': 50000,
#    'memory_size': 400128,
#    'n_negative': 0,
#    'p_negative': 0.0,
#    'n_infinite': 0,
#    'n_zeros': 4539,
#    'mean': 5.00388,
#    'std': 3.1650821949052146,
#    'variance': 10.01774530050601,
#    'min': 0,
#    'max': 10,
#    'kurtosis': -1.2235775386900873,
#    'skewness': -0.0021928432558807396,
#    'sum': 250194,
#    'mad': 3.0,
#    'chi_squared': {'statistic': 90918.40004000001, 'pvalue': 0.0},
#    'range': 10,
#    '5%': 0.0,
#    '25%': 2.0,
#    '50%': 5.0,
#    '75%': 8.0,
#    '95%': 10.0,
#    'iqr': 6.0,
#    'cv': 0.6325255991161288,
#    'p_zeros': 0.09078,
#    'p_infinite': 0.0,
#    'monotonic_increase': False,
#    'monotonic_decrease': False,
#    'monotonic_increase_strict': False,
#    'monotonic_decrease_strict': False,
#    'monotonic': 0,
#    'histogram': {'counts': [4539,
#      4588,
#      4500,
#      4528,
#      4578,
#      4527,
#      4471,
#      4578,
#      4555,
#      4597,
#      4539],
#     'bin_edges': [0.0,
#      0.9090909090909091,
#      1.8181818181818181,
#      2.727272727272727,
#      3.6363636363636362,
#      4.545454545454545,
#      5.454545454545454,
#      6.363636363636363,
#      7.2727272727272725,
#      8.181818181818182,
#      9.09090909090909,
#      10.0]}}},
#  'alerts': ['[HIGH_CARDINALITY] alert on column First Name',
#   '[HIGH_CARDINALITY] alert on column Last Name',
#   '[HIGH_CARDINALITY] alert on column Email',
#   '[HIGH_CARDINALITY] alert on column Application Date',
#   '[HIGH_CARDINALITY] alert on column Country',
#   '[UNIFORM] alert on column Email',
#   '[ZEROS] alert on column YOE',
#   '[ZEROS] alert on column Code Challenge Score',
#   '[ZEROS] alert on column Technical Interview Score']}

# %%
profile.to_widgets()
# Out:
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]
# Render widgets:   0%|          | 0/1 [00:00<?, ?it/s]
# VBox(children=(Tab(children=(Tab(children=(GridBox(children=(VBox(children=(GridspecLayout(children=(HTML(valu…
